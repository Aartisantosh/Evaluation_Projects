# %% [markdown]
# Baseball Case Study
#
# Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# -- Output: Number of predicted wins (W)
#
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %%
#Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
#Extract dataset csv file

data = pd.read_csv('baseball.csv')

# %%
#display the datset
data
# Out:
#     Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42        139    383         973
# 1     83   696     5467  1349      277       44        156    439        1264
# 2     81   669     5439  1395      303       29        141    533        1157
# 3     76   622     5533  1381      260       27        136    404        1231
# 4     74   689     5605  1515      289       49        151    455        1259
# 5     93   891     5509  1480      308       17        232    570        1151
# 6     87   764     5567  1397      272       19        212    554        1227
# 7     81   713     5485  1370      246       20        217    418        1331
# 8     80   644     5485  1383      278       32        167    436        1310
# 9     78   748     5640  1495      294       33        161    478        1148
# 10    88   751     5511  1419      279       32        172    503        1233
# 11    86   729     5459  1363      278       26        230    486        1392
# 12    85   661     5417  1331      243       21        176    435        1150
# 13    76   656     5544  1379      262       22        198    478        1336
# 14    68   694     5600  1405      277       46        146    475        1119
# 15   100   647     5484  1386      288       39        137    506        1267
# 16    98   697     5631  1462      292       27        140    461        1322
# 17    97   689     5491  1341      272       30        171    567        1518
# 18    68   655     5480  1378      274       34        145    412        1299
# 19    64   640     5571  1382      257       27        167    496        1255
# 20    90   683     5527  1351      295       17        177    488        1290
# 21    83   703     5428  1363      265       13        177    539        1344
# 22    71   613     5463  1420      236       40        120    375        1150
# 23    67   573     5420  1361      251       18        100    471        1107
# 24    63   626     5529  1374      272       37        130    387        1274
# 25    92   667     5385  1346      263       26        187    563        1258
# 26    84   696     5565  1486      288       39        136    457        1159
# 27    79   720     5649  1494      289       48        154    490        1312
# 28    74   650     5457  1324      260       36        148    426        1327
# 29    68   737     5572  1479      274       49        186    388        1283
#
#     Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Complete_Games  Shutouts  \
# 0            104           641          601  3.73               2         8
# 1             70           700          653  4.07               2        12
# 2             86           640          584  3.67              11        10
# 3             68           701          643  3.98               7         9
# 4             83           803          746  4.64               7        12
# 5             88           670          609  3.80               7        10
# 6             63           698          652  4.03               3         4
# 7             44           693          646  4.05               0        10
# 8             87           642          604  3.74               1        12
# 9             71           753          694  4.31               3        10
# 10           101           733          680  4.24               5         9
# 11           121           618          572  3.57               5        13
# 12            52           675          630  3.94               2        12
# 13            69           726          677  4.16               6        12
# 14            78           729          664  4.14               5        15
# 15            69           525          478  2.94               1        15
# 16            98           596          532  3.21               0        13
# 17            95           608          546  3.36               6        21
# 18            84           737          682  4.28               1         7
# 19           134           754          700  4.33               2         8
# 20            51           613          557  3.43               1        14
# 21            57           635          577  3.62               4        13
# 22           112           678          638  4.02               0        12
# 23            69           760          698  4.41               3        10
# 24            88           809          749  4.69               1         7
# 25            59           595          553  3.44               6        21
# 26            93           627          597  3.72               7        18
# 27           132           713          659  4.04               1        12
# 28            82           731          655  4.09               1         6
# 29            97           844          799  5.04               4         4
#
#     Saves  Errors
# 0      56      88
# 1      45      86
# 2      38      79
# 3      37     101
# 4      35      86
# 5      34      88
# 6      48      93
# 7      43      77
# 8      60      95
# 9      40      97
# 10     45     119
# 11     39      85
# 12     46      93
# 13     45      94
# 14     28     126
# 15     62      96
# 16     54     122
# 17     48     111
# 18     40     116
# 19     35      90
# 20     50      88
# 21     41      90
# 22     35      77
# 23     44      90
# 24     35     117
# 25     47      75
# 26     41      78
# 27     44      86
# 28     41      92
# 29     36      95

# %%
#renaming the columns

data.rename(columns = {'W':'Wins', 'R':'Runs', 'AB':'At_Bats', 'H':'Hits', '2B':'Doubles', '3B':'Triples', 
                       'HR':'Home_Runs', 'BB':'Walks', 'SO':'Strikeouts', 'SB':'Stolen_Bases', 'RA':'Runs_Allowed', 
                       'ER':'Earned_Runs', 'CG':'Complete_Games', 'SHO':'Shutouts', 'SV':'Saves', 'E':'Errors'},inplace = True)

#display the data after renaming
data.head()
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42        139    383         973
# 1    83   696     5467  1349      277       44        156    439        1264
# 2    81   669     5439  1395      303       29        141    533        1157
# 3    76   622     5533  1381      260       27        136    404        1231
# 4    74   689     5605  1515      289       49        151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Complete_Games  Shutouts  \
# 0           104           641          601  3.73               2         8
# 1            70           700          653  4.07               2        12
# 2            86           640          584  3.67              11        10
# 3            68           701          643  3.98               7         9
# 4            83           803          746  4.64               7        12
#
#    Saves  Errors
# 0     56      88
# 1     45      86
# 2     38      79
# 3     37     101
# 4     35      86

# %%
#To check the column names in our dataset
data.columns
# Out:
# Index(['Wins', 'Runs', 'At_Bats', 'Hits', 'Doubles', 'Triples', 'Home_Runs',
#        'Walks', 'Strikeouts', 'Stolen_Bases', 'Runs_Allowed', 'Earned_Runs',
#        'ERA', 'Complete_Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
#To check the dataset dimension
data.shape
# Out:
# (30, 17)

# %% [markdown]
# # Statistical Summary

# %%
#Let's check whether we have null values in our dataset
data.isna().sum()
# Out:
# Wins              0
# Runs              0
# At_Bats           0
# Hits              0
# Doubles           0
# Triples           0
# Home_Runs         0
# Walks             0
# Strikeouts        0
# Stolen_Bases      0
# Runs_Allowed      0
# Earned_Runs       0
# ERA               0
# Complete_Games    0
# Shutouts          0
# Saves             0
# Errors            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wins            30 non-null     int64
#  1   Runs            30 non-null     int64
#  2   At_Bats         30 non-null     int64
#  3   Hits            30 non-null     int64
#  4   Doubles         30 non-null     int64
#  5   Triples         30 non-null     int64
#  6   Home_Runs       30 non-null     int64
#  7   Walks           30 non-null     int64
#  8   Strikeouts      30 non-null     int64
#  9   Stolen_Bases    30 non-null     int64
#  10  Runs_Allowed    30 non-null     int64
#  11  Earned_Runs     30 non-null     int64
#  12  ERA             30 non-null     float64
#  13  Complete_Games  30 non-null     int64
#  14  Shutouts        30 non-null     int64
#  15  Saves           30 non-null     int64
#  16  Errors          30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Let's visualize to check the nullvalues in our dataset

plt.figure(figsize = [12,8])
sns.heatmap(data.isnull())
plt.title('Null Values')
plt.show()

# %% [markdown]
# # Observation:
# We can clearly see that there is no null values in our dataset

# %%
#lets check our column data types

data.dtypes
# Out:
# Wins                int64
# Runs                int64
# At_Bats             int64
# Hits                int64
# Doubles             int64
# Triples             int64
# Home_Runs           int64
# Walks               int64
# Strikeouts          int64
# Stolen_Bases        int64
# Runs_Allowed        int64
# Earned_Runs         int64
# ERA               float64
# Complete_Games      int64
# Shutouts            int64
# Saves               int64
# Errors              int64
# dtype: object

# %% [markdown]
# Observation:
#
# Feature "ERA" is the only column with float values
#
# And rest all other features are of integer values

# %%
data.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home_Runs       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# 25%    23.000000  140.250000  428.250000  1157.50000     69.000000
# 50%    31.000000  158.500000  473.000000  1261.50000     83.500000
# 75%    39.000000  177.000000  501.250000  1311.50000     96.500000
# max    49.000000  232.000000  570.000000  1518.00000    134.000000
#
#        Runs_Allowed  Earned_Runs        ERA  Complete_Games   Shutouts  \
# count     30.000000    30.000000  30.000000       30.000000  30.000000
# mean     688.233333   635.833333   3.956333        3.466667  11.300000
# std       72.108005    70.140786   0.454089        2.763473   4.120177
# min      525.000000   478.000000   2.940000        0.000000   4.000000
# 25%      636.250000   587.250000   3.682500        1.000000   9.000000
# 50%      695.500000   644.500000   4.025000        3.000000  12.000000
# 75%      732.500000   679.250000   4.220000        5.750000  13.000000
# max      844.000000   799.000000   5.040000       11.000000  21.000000
#
#            Saves      Errors
# count  30.000000   30.000000
# mean   43.066667   94.333333
# std     7.869335   13.958889
# min    28.000000   75.000000
# 25%    37.250000   86.000000
# 50%    42.000000   91.000000
# 75%    46.750000   96.750000
# max    62.000000  126.000000

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %% [markdown]
# Let us explore our data and visualize it

# %% [markdown]
# # Univariate Analysis

# %%
#Target column - Wins

plt.figure(figsize = (14,6))
plt.style.use('seaborn')
sns.countplot(data['Wins'])
plt.title('Winning Estimations')
plt.show()

# %%
#Let's check for the How all our columns are distributed

for i in data.columns:
    plt.figure(figsize = (8,6))
    sns.distplot(data[i])
    plt.title(i)
plt.show()

# %% [markdown]
# Skewness is present in some of the columns, we will checkfor the outliers and remove them

# %%
plt.figure(figsize = (15,23))
plotnumber = 1

for column in data.iloc[:,1:]: #let's visualize only the features columns 
    if plotnumber<=16:
        ax = plt.subplot(8,2,plotnumber)
        sns.boxplot(data[column],color = 'Green')
        plt.xlabel(column,fontsize = 20)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# Observation:
# - We could see some outliers in the following features
#     Runs
#     ERA
#     Shutouts
#     Saves
#     Errors
# - We shall remove the outliers with some techniques

# %% [markdown]
# # Bivariate Analysis

# %%
# At Bats vs Wins

plt.figure(figsize=(30,10))
plt.title('At Bats vs Wins')
sns.barplot(x='At_Bats',y='Wins',data=data)
# Out:
# <Axes: title={'center': 'At Bats vs Wins'}, xlabel='At_Bats', ylabel='Wins'>

# %%
# 'Hits vs Runs'

plt.figure(figsize=(15,5))
plt.title('Hits vs Runs')
sns.lineplot(x='Hits',y='Runs',data=data)
plt.show()

# %%
#to check the maximum value of Runs Column
data['Runs'].max()
# Out:
# 891

# %%
 #to extract the row that has the maximum run
data[data['Runs'] ==891]
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 5    93   891     5509  1480      308       17        232    570        1151
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs  ERA  Complete_Games  Shutouts  \
# 5            88           670          609  3.8               7        10
#
#    Saves  Errors
# 5     34      88

# %% [markdown]
# Observation:
# We can see that highest runs "891" were scored when the Number of Hits was "1480"
#
# In the ranger of (1422 - 1477) as no. of hits were increasing the number of runs were also increasing

# %%
#Earned Runs vs Earned Runs Average
plt.figure(figsize=(30,6))
plt.title('Earned Runs vs Earned Runs Average')
sns.barplot(x='Earned_Runs',y='ERA',data=data)
# Out:
# <Axes: title={'center': 'Earned Runs vs Earned Runs Average'}, xlabel='Earned_Runs', ylabel='ERA'>

# %% [markdown]
# Observation:
# If the number of Runs earned increases then, the Earned Runs Average also increases
#
# By this we can also say that our "Earned Runs" and "Earned Runs Average" data are consistent

# %% [markdown]
# # Multivariate Analysis

# %%
data_corr = data.corr().abs() #to get the correlation values

plt.figure(figsize=(12,8))
sns.heatmap(data_corr,vmin=-1,vmax=1,square=True,center=1,fmt='.1g',cmap='mako',annot=True)

plt.tight_layout()

# %%
# to check and display the correlation table
data.corr()
# Out:
#                     Wins      Runs   At_Bats      Hits   Doubles   Triples  \
# Wins            1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118
# Runs            0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072
# At_Bats        -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422
# Hits            0.037612  0.482856  0.739122  1.000000  0.566847  0.478694
# Doubles         0.427797  0.560084  0.453370  0.566847  1.000000  0.220490
# Triples        -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000
# Home_Runs       0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915
# Walks           0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949
# Strikeouts      0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196
# Stolen_Bases   -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437
# Runs_Allowed   -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125
# Earned_Runs    -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225
# ERA            -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951
# Complete_Games  0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898
# Shutouts        0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396
# Saves           0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370
# Errors         -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678
#
#                 Home_Runs     Walks  Strikeouts  Stolen_Bases  Runs_Allowed  \
# Wins             0.307407  0.484342    0.111850     -0.157234     -0.812952
# Runs             0.671283  0.402452   -0.054726      0.081367     -0.041623
# At_Bats         -0.066983 -0.136414   -0.106022      0.372618      0.316010
# Hits            -0.090855 -0.118281   -0.398830      0.413444      0.224324
# Doubles          0.056292  0.302700   -0.150752      0.195027     -0.218160
# Triples         -0.430915 -0.454949   -0.141196      0.457437      0.314125
# Home_Runs        1.000000  0.425691    0.359923     -0.136567     -0.103903
# Walks            0.425691  1.000000    0.233652     -0.098347     -0.416445
# Strikeouts       0.359923  0.233652    1.000000      0.030968     -0.129745
# Stolen_Bases    -0.136567 -0.098347    0.030968      1.000000      0.132290
# Runs_Allowed    -0.103903 -0.416445   -0.129745      0.132290      1.000000
# Earned_Runs     -0.085922 -0.452663   -0.161612      0.143068      0.991018
# ERA             -0.090917 -0.459832   -0.180368      0.126063      0.986674
# Complete_Games   0.156502  0.462478   -0.093418     -0.020783     -0.016659
# Shutouts        -0.019119  0.426004    0.237721     -0.106563     -0.636862
# Saves           -0.028540  0.099445    0.126297     -0.183418     -0.616224
# Errors          -0.207597 -0.075685    0.155133      0.079149      0.198996
#
#                 Earned_Runs       ERA  Complete_Games  Shutouts     Saves  \
# Wins              -0.809435 -0.819600        0.080533  0.471805  0.666530
# Runs              -0.041245 -0.049281        0.232042 -0.103274 -0.096380
# At_Bats            0.309686  0.255551       -0.080876 -0.197321 -0.106367
# Hits               0.252489  0.231172        0.147955 -0.145559 -0.130371
# Doubles           -0.235531 -0.254854        0.306675  0.057998  0.171576
# Triples            0.340225  0.330951       -0.065898 -0.041396 -0.142370
# Home_Runs         -0.085922 -0.090917        0.156502 -0.019119 -0.028540
# Walks             -0.452663 -0.459832        0.462478  0.426004  0.099445
# Strikeouts        -0.161612 -0.180368       -0.093418  0.237721  0.126297
# Stolen_Bases       0.143068  0.126063       -0.020783 -0.106563 -0.183418
# Runs_Allowed       0.991018  0.986674       -0.016659 -0.636862 -0.616224
# Earned_Runs        1.000000  0.997248       -0.020221 -0.630192 -0.589663
# ERA                0.997248  1.000000       -0.009856 -0.630833 -0.607005
# Complete_Games    -0.020221 -0.009856        1.000000  0.241676 -0.367766
# Shutouts          -0.630192 -0.630833        0.241676  1.000000  0.221639
# Saves             -0.589663 -0.607005       -0.367766  0.221639  1.000000
# Errors             0.136921  0.113137       -0.140047 -0.115716 -0.025636
#
#                   Errors
# Wins           -0.089485
# Runs           -0.023262
# At_Bats         0.316743
# Hits           -0.033173
# Doubles         0.105754
# Triples         0.126678
# Home_Runs      -0.207597
# Walks          -0.075685
# Strikeouts      0.155133
# Stolen_Bases    0.079149
# Runs_Allowed    0.198996
# Earned_Runs     0.136921
# ERA             0.113137
# Complete_Games -0.140047
# Shutouts       -0.115716
# Saves          -0.025636
# Errors          1.000000

# %% [markdown]
# "Earned_Runs", "ERA" are highly correlated with "Runs_Allowed" and each other respectively

# %% [markdown]
# Removing Outliers and Skewness:

# %%
#columns with outliers
outliers = ['Runs', 'Shutouts','Saves','ERA', 'Errors']

# %% [markdown]
# Applying IQR Method

# %%
Q1 = data[outliers].quantile(0.25)
Q3 = data[outliers].quantile(0.75)
IQR = Q3-Q1

data_new1 = data[~((data[outliers] < (Q1-1.5*IQR)) | (data[outliers]> (Q3 + 1.5*Q3))).any(axis = 1)]

# %%
data_new1 = data[data['Wins'] > 10]  # Just a hypothetical operation for demonstration

# Then you can print the shape information
print('Shape - Before and After:\n')
print('Shape Before'.ljust(20), ":", data.shape)
print('Shape After'.ljust(20), ":", data_new1.shape)
print('Percentage Loss'.ljust(20), ":", ((data.shape[0] - data_new1.shape[0]) / data.shape[0]) * 100)
# Out:
# Shape - Before and After:
#
# Shape Before         : (30, 17)
# Shape After          : (30, 17)
# Percentage Loss      : 0.0

# %% [markdown]
# Applying z-score Method

# %%
#importing libraries

from scipy.stats import zscore


z=np.abs(zscore(data[outliers]))
threshold = 3
data_new2 = data[(z<3).all(axis=1)]

# %%
print('Shape - Before and After:\n')
print('Shape Before'.ljust(20),":",data.shape)
print('Shape After'.ljust(20),":",data_new2.shape)
print('Percentage Loss'.ljust(20),":",((data.shape[0]-data_new2.shape[0])/data.shape[0])*100)
# Out:
# Shape - Before and After:
#
# Shape Before         : (30, 17)
# Shape After          : (29, 17)
# Percentage Loss      : 3.3333333333333335

# %% [markdown]
# Observation:
# - We could see by the IQR method, there is no change in our dataset and the percentage loss is '0' that means IQR method has not removed any outliers
#
# - We could see by the Z-score method there is a change in our dataset from "(30, 17) to (29, 17)" and percentage loss is "3.3333333333333335 %" which is less loss, that means z-score method has helped us in removing some of the outliers
#
# Hence, we will proceed with z-score method

# %%
data_new = data_new2.copy()   #to make a copy
data_new.shape #our new dimensions
# Out:
# (29, 17)

# %%
data_new.skew()
# Out:
# Wins              0.119013
# Runs             -0.215364
# At_Bats           0.169573
# Hits              0.783772
# Doubles          -0.335304
# Triples           0.090124
# Home_Runs         0.450862
# Walks             0.151193
# Strikeouts       -0.233815
# Stolen_Bases      0.494966
# Runs_Allowed      0.018155
# Earned_Runs       0.018461
# ERA               0.016693
# Complete_Games    0.854980
# Shutouts          0.526943
# Saves             0.627480
# Errors            0.840271
# dtype: float64

# %% [markdown]
# We found that we still have some Skewness in the following features
#
# Positive Skewness
#
# Hits : 0.783772
#
# Colmplete_Games : 0.854980
#
# Shutouts : 0.526943
#
# Saves : 0.627480
#
# Errors : 0.840271

# %%
#Let's remove/reduce the skewness by using power_transform

from sklearn.preprocessing import PowerTransformer #importing the library

scaler = PowerTransformer(method='yeo-johnson')
    
data_new['Hits'] = scaler.fit_transform(data_new['Hits'].values.reshape(-1,1))
data_new['Complete_Games'] = scaler.fit_transform(data_new['Complete_Games'].values.reshape(-1,1))
data_new['Shutouts'] = scaler.fit_transform(data_new['Shutouts'].values.reshape(-1,1))
data_new['Saves'] = scaler.fit_transform(data_new['Saves'].values.reshape(-1,1))
data_new['Errors'] = scaler.fit_transform(data_new['Errors'].values.reshape(-1,1))

# %%
#check skewness after applying the power transformation technique
data_new.skew()
# Out:
# Wins              0.119013
# Runs             -0.215364
# At_Bats           0.169573
# Hits              0.000000
# Doubles          -0.335304
# Triples           0.090124
# Home_Runs         0.450862
# Walks             0.151193
# Strikeouts       -0.233815
# Stolen_Bases      0.494966
# Runs_Allowed      0.018155
# Earned_Runs       0.018461
# ERA               0.016693
# Complete_Games   -0.045947
# Shutouts          0.000529
# Saves            -0.000925
# Errors            0.065585
# dtype: float64

# %% [markdown]
# # Splitting Features and Labels

# %%
X = data_new.drop(columns = 'Wins')  #Features
Y = data_new['Wins'] #Label

# %%
#let's check for our dimensions after splitting the data

print('Features dimension:\t',X.shape,'\nLabel Dimension:\t',Y.shape)
# Out:
# Features dimension:	 (29, 16)
# Label Dimension:	 (29,)

# %% [markdown]
# We can now see that features dimension contains 29 rows and 16 columns
#
# And our target data dimension as 29 rows and a single column(W - Wins)

# %% [markdown]
# # Scaling

# %% [markdown]
# We could see that there is a huge difference in data range between different columns data in our dataset. Hence, we need to scale the data.

# %%
#let's use StandardScaler method to normalize the data

from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()

X_scaled = Scaler.fit_transform(X)

# %% [markdown]
# # Finding Best Random State

# %%
#Let's find out the best Random State which can be used for all our models
from sklearn.linear_model import LinearRegression

maxR2_Score = 0
maxRS = 0

for i in range(150):
    x_train,x_test,y_train,y_test = train_test_split(X_scaled,Y,test_size = 0.20,random_state = i)
    LR = LinearRegression()
    LR.fit(x_train,y_train)
    predrf = LR.predict(x_test)
    Score = r2_score(y_test,predrf)
    if Score>maxR2_Score:
        maxR2_Score = Score
        maxRS = i
        
print('The best accuracy is ',maxR2_Score, ' with Random State ',maxRS)
# Out:
# The best accuracy is  0.9502062449780093  with Random State  106

# %% [markdown]
# Train Test Split

# %%
#Let's split our dataset for training and testing purpose

x_train,x_test,y_train,y_test = train_test_split(X_scaled, Y, test_size =0.20, random_state = maxRS)

# %% [markdown]
# # Model Building

# %% [markdown]
# let's build multiple models and check for the best model by using the Cross_val_score metrics

# %%
# Model: Linear Regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train,y_train)

y_pred_lr = lr.predict(x_test)

R1 = r2_score(y_test, y_pred_lr)
print('R Squared (R2): ',R1)
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred_lr))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred_lr)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred_lr))

C1 = cross_val_score(lr,X_scaled,Y,cv=3).mean()

print('Cross validation Score: ', C1)
# Out:
# R Squared (R2):  0.9502062449780093
# Mean Squared Error (MSE):  8.332155007013116
# Root Mean Squared Error (RMSE):  2.8865472466275546
# Mean Absolute Error (MAE):  2.6354861006404966
# Cross validation Score:  -1.0953770383978503

# %% [markdown]
# CV score is in negative, Hence, Linear Regression is not a Good model for our model building.

# %% [markdown]
# ### Model: Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rand = RandomForestRegressor(max_features='sqrt')
rand.fit(x_train,y_train)

y_pred_rand = rand.predict(x_test)

R2 = r2_score(y_test, y_pred_rand)
print('R Squared (R2): ',R2)
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred_rand))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred_rand)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred_rand))

C2 = cross_val_score(rand,X_scaled,Y,cv=3).mean()
print('Cross validation Score: ', C2)
# Out:
# R Squared (R2):  0.6648463147410357
# Mean Squared Error (MSE):  56.08238333333335
# Root Mean Squared Error (RMSE):  7.4888172185822075
# Mean Absolute Error (MAE):  6.291666666666667
# Cross validation Score:  0.05634128277353997

# %% [markdown]
# ### Model: KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn = KNeighborsRegressor()
kn.fit(x_train,y_train)

y_pred_kn = kn.predict(x_test)

R3 = r2_score(y_test, y_pred_kn)
print('R Squared (R2): ',R3)
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred_kn))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred_kn)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred_kn))

C3 = cross_val_score(kn,X_scaled,Y,cv=3).mean()
print('Cross validation Score: ', C3)
# Out:
# R Squared (R2):  0.577410358565737
# Mean Squared Error (MSE):  70.71333333333335
# Root Mean Squared Error (RMSE):  8.409122031064442
# Mean Absolute Error (MAE):  7.566666666666667
# Cross validation Score:  0.2405283542792324

# %% [markdown]
# ### Model: Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(max_features='sqrt')
gb.fit(x_train,y_train)

y_pred_gb = gb.predict(x_test)

R4 = r2_score(y_test, y_pred_gb)
print('R Squared (R2): ',R4)
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred_gb))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred_gb)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred_gb))

C4 = cross_val_score(gb,X_scaled,Y,cv=3).mean()
print('Cross validation Score: ', C4)
# Out:
# R Squared (R2):  0.611420429605766
# Mean Squared Error (MSE):  65.02231477930182
# Root Mean Squared Error (RMSE):  8.063641533407957
# Mean Absolute Error (MAE):  7.152798957802136
# Cross validation Score:  -0.22952689748263885

# %% [markdown]
# ### Model: Ridge

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(x_train,y_train)

y_pred_ridge = ridge.predict(x_test)
R5 = r2_score(y_test, y_pred_ridge)

print('R Squared (R2): ',R5)
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred_ridge))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred_ridge)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred_ridge))
C5 = cross_val_score(ridge,X_scaled,Y,cv=3).mean()
print('Cross validation Score: ', C5)
# Out:
# R Squared (R2):  0.8603305777539426
# Mean Squared Error (MSE):  23.37134998917361
# Root Mean Squared Error (RMSE):  4.83439241158324
# Mean Absolute Error (MAE):  4.060877260616446
# Cross validation Score:  0.5087298107243878

# %% [markdown]
# ### Model: Lasso

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()
lasso.fit(x_train,y_train)

y_pred_Lasso = lasso.predict(x_test)
R6 = r2_score(y_test, y_pred_Lasso)

print('R Squared (R2): ',R6)
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred_Lasso))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred_Lasso)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred_Lasso))

C6 = cross_val_score(lasso,X_scaled,Y,cv=3).mean()
print('Cross validation Score: ', C6)
# Out:
# R Squared (R2):  0.8446509198956683
# Mean Squared Error (MSE):  25.995079404124834
# Root Mean Squared Error (RMSE):  5.098536986638896
# Mean Absolute Error (MAE):  4.420222287843354
# Cross validation Score:  0.6682700434793617

# %%
R4 = 0.6347818819694171
C4 = 0.17731100244106335

# %% [markdown]
# # Finding the best model

# %%
Overall_Score = pd.DataFrame({'Model':['Random Forest Regressor','KNeighbors Regressor','Gradient Boosting Regressor','Ridge','Lasso'],
                              'R2_Score':[R2,R3,R4,R5,R6],
                              'Cross_Validation_Score':[C2,C3,C4,C5,C6]})
Overall_Score['Difference'] = Overall_Score['R2_Score'] - Overall_Score['Cross_Validation_Score']

# %%
Overall_Score
# Out:
#                          Model  R2_Score  Cross_Validation_Score  Difference
# 0      Random Forest Regressor  0.664846                0.056341    0.608505
# 1         KNeighbors Regressor  0.577410                0.240528    0.336882
# 2  Gradient Boosting Regressor  0.634782                0.177311    0.457471
# 3                        Ridge  0.860331                0.508730    0.351601
# 4                        Lasso  0.844651                0.668270    0.176381

# %%
#Let's check the model row with minimum difference of R2_score and Cross_Validation Score
Overall_Score['Difference'].min()
# Out:
# 0.17638087641630662

# %%
Overall_Score[Overall_Score['Difference']==0.17638087641630662]
# Out:
#    Model  R2_Score  Cross_Validation_Score  Difference
# 4  Lasso  0.844651                 0.66827    0.176381

# %% [markdown]
# Here, if we check as per the R2_Score then, "Ridge" is the best model, but if we go with less difference
# between r2 score and cross validation score, we will find, 'Lasso' as our best model.

# %% [markdown]
# Our best model is 'Lasso'

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

#parameters
param_grid = {'alpha':[0.02, 0.024, 0.025, 0.026, 0.03],'fit_intercept':[True],'random_state':range(1,10),
              'max_iter':[10,100,1000,10000],'copy_X':[True],}   

gridsearch=GridSearchCV(estimator = Lasso(), param_grid = param_grid,scoring='r2',cv=5)     

gridsearch.fit(x_train,y_train) #training
print(gridsearch.best_score_, gridsearch.best_params_)  #finding the best parameters
# Out:
# -0.7595016771096815 {'alpha': 0.03, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10, 'random_state': 1}

# %%
#Applying the best parameters and building the model

Lasso_final = Lasso(alpha = 0.03, fit_intercept = True, max_iter = 10, copy_X=True, random_state= 1)  

Lasso_final.fit(x_train,y_train) #training

y_pred = Lasso_final.predict(x_test)  #testing

# %% [markdown]
# ### Saving the Model

# %%
import joblib
joblib.dump(Lasso_final,'BaseBall_Predictions.obj')
# Out:
# ['BaseBall_Predictions.obj']

# %% [markdown]
# ### Before Tuning:

# %%
data_view1 = pd.DataFrame({'Actual':y_test , 'Predictions':y_pred_Lasso},columns=['Actual','Predictions'])
sns.lmplot(x='Actual',y='Predictions',data=data_view1,palette='rainbow')
data_view1
# Out:
#     Actual  Predictions
# 9       78    79.140719
# 29      68    68.558871
# 18      68    74.231218
# 23      67    72.734824
# 0       95    88.517002
# 16      98    91.627296

# %% [markdown]
# ### After Tuning:

# %%
data_view2 = pd.DataFrame({'Y Test':y_test , 'Pred':y_pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data_view2,palette='rainbow')
data_view2
# Out:
#     Y Test       Pred
# 9       78  77.639957
# 29      68  70.675918
# 18      68  73.731627
# 23      67  68.725682
# 0       95  87.171152
# 16      98  88.996748

# %% [markdown]
# Before and after tuning the Lasso model we can see that there is a change in the predictions values and now it is more   closure to the actual values

# %% [markdown]
# Performance Metrix:

# %%
print('R Squared (R2): ',r2_score(y_test, y_pred))
print('Mean Squared Error (MSE): ',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error (RMSE): ',np.sqrt(mean_squared_error(y_test, y_pred)))
print('Mean Absolute Error (MAE): ',mean_absolute_error(y_test,y_pred))
# Out:
# R Squared (R2):  0.815269814038971
# Mean Squared Error (MSE):  30.91151778414552
# Root Mean Squared Error (RMSE):  5.559812747219596
# Mean Absolute Error (MAE):  4.554228219149269

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# plot LOO predictions against actual
plot_LOO = sns.scatterplot(x=y_test, y=y_pred)
plot_LOO.set(xlabel='Actual', ylabel='Prediction')

# generate and graph y = x line
x_plot = np.linspace(min(y_test.min(), y_pred.min()), max(y_test.max(), y_pred.max()), 100)
y_plot = x_plot
plt.plot(x_plot, y_plot, color='r', linestyle='--')  # Plotting y = x line

plt.title("Actual vs Predictions")
plt.show()

# %%
#Load the saved model

loaded_model = joblib.load(open('BaseBall_Predictions.obj','rb'))

# %%
# Calculate the accuracy score and predict target values

# Calculate the Score 
score = loaded_model.score(x_test,y_test) 

# Print the Score
print("Test score: {0:.2f} %".format(100 * score))

# Predict the Labels using the reloaded Model
Predictions = loaded_model.predict(x_test)

Predictions
# Out:
# Test score: 81.53 %
# array([77.63995744, 70.67591775, 73.73162713, 68.7256815 , 87.17115187,
#        88.99674775])

# %%
#plot predicted vs. actual values

plt.figure(figsize=[15,6])
sns.lineplot(x=y_pred, y=y_test)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Predicted vs. Actual Values')
plt.show()

# %%
#create dataframe of actual and predicted values

list_of_tuples = list(zip(y_test, y_pred))
Result = pd.DataFrame(list_of_tuples,
                  columns = ['Actual', 'Predicted'])
Result   #Show the actual and predicted data values
# Out:
#    Actual  Predicted
# 0      78  77.639957
# 1      68  70.675918
# 2      68  73.731627
# 3      67  68.725682
# 4      95  87.171152
# 5      98  88.996748

# %% [markdown]
# ### Our model is now ready to predict Baseball Match Wins of a team
